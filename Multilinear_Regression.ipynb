# %% [markdown]
# <a href="https://colab.research.google.com/github/TimoCodez/Python-BIA/blob/main/Multilinear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries Directory and data

# %%
# %cd /content/drive/MyDrive/business_analyst/Statistics and Descriptive Analytics/Multilinear Regression
# Out:
# /content/drive/MyDrive/business_analyst/Statistics and Descriptive Analytics/Multilinear Regression

# %%
#Libraries
import pandas as pd
import statsmodels.api as sm
import numpy as np
import seaborn as sns

# %%
#load the data
df = pd.read_csv('salaries.csv')
df.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %% [markdown]
# # Analysing the data

# %%
#summary statistics
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
#plotting continuous independent values (IV) vs dependant variable
#so in this case its salary vs yrs service and salary vs yrs since phd so is there correlation
sns.set(font_scale = 2) #set bigger font
sns.pairplot(data = df,
             y_vars = ['salary'],
             x_vars = ['yrs.service', 'yrs.since.phd'],
             height = 6)#set bigger scale

# %%
# Correlation matrix
sns.heatmap(df.corr(),
    annot = True,
    fmt = '.2g',
    center = 0,
    cmap = 'viridis',
    linewidths = 1,
    linecolor = 'black'
)
# Out:
# <ipython-input-6-f76fe769564a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),
# <Axes: >

# %%
# Categorical variables
df['rank'].value_counts()
df.select_dtypes(include = 'object').value_counts()
# Out:
# rank       discipline  sex
# Prof       B           Male      125
#            A           Male      123
# AsstProf   B           Male       38
# AssocProf  B           Male       32
#            A           Male       22
# AsstProf   A           Male       18
# Prof       B           Female     10
#            A           Female      8
# AssocProf  B           Female      6
# AsstProf   A           Female      6
#            B           Female      5
# AssocProf  A           Female      4
# dtype: int64
